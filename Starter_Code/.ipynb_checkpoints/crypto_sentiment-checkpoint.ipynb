# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from newsapi import NewsApiClient
import spacy
from spacy import displacy

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
news_bitcoin_en = newsapi.get_everything(
    q="bitcoin",
    language="en"
)

# %%
# Fetch the Ethereum news articles
news_ethereum_en = newsapi.get_everything(
    q="ethereum",
    language="en"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
 
bitcoin_sentiments = []

for article in news_bitcoin_en["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-01-12  When Denis Rusinovich set up cryptocurrency mi...    0.0000
# 1  2022-01-25  El Salvador introduced Bitcoin as a legal tend...    0.3182
# 2  2022-01-14  Were officially building an open Bitcoin minin...   -0.4404
# 3  2022-01-27  Israeli national Tal Prihar pled guilty to rou...   -0.3182
# 4  2022-01-20  In a new blog post the company said that 4,836...    0.0000
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.105     0.000    0.895
# 2     0.000     0.083    0.917
# 3     0.045     0.084    0.871
# 4     0.000     0.000    1.000

# %%
# Create the Ethereum sentiment scores DataFrame
 
ethereum_sentiments = []

for article in news_ethereum_en["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-01-20  In a new blog post the company said that 4,836...    0.0000
# 1  2022-01-19  Hackers who made off with roughly $15 million ...    0.0000
# 2  2022-01-20  On some level, the new mayor is simply employi...    0.1779
# 3  2022-01-21  Back in September\r\n, Robinhood announced pla...    0.0772
# 4  2022-01-20  Trading platform Crypto.com lost about $34 mil...   -0.1027
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.000     0.000    1.000
# 2     0.052     0.000    0.948
# 3     0.038     0.000    0.962
# 4     0.056     0.067    0.877

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.050560   0.062550   0.037900   0.899550
# std     0.376771   0.061657   0.043444   0.063682
# min    -0.440400   0.000000   0.000000   0.765000
# 25%    -0.331550   0.000000   0.000000   0.866250
# 50%     0.038600   0.054000   0.000000   0.914500
# 75%     0.328950   0.106750   0.083250   0.934000
# max     0.680800   0.185000   0.101000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.194960   0.059850   0.008700   0.931400
# std     0.269264   0.067117   0.021502   0.073004
# min    -0.102700   0.000000   0.000000   0.783000
# 25%     0.000000   0.000000   0.000000   0.889750
# 50%     0.038600   0.043500   0.000000   0.951000
# 75%     0.421500   0.106000   0.000000   1.000000
# max     0.757900   0.217000   0.067000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin has higher mean positive score of 0.062550 than Ethereu which 0.059850
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum had the highest compund scoree
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum had the highest positive score

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
import nltk
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    words = nltk.word_tokenize(text)
    words = [word.lower() for word in words if word.isalpha()]
    str_words = ' '.join(str(e) for e in words)
    # Create custom stopwords
    sw_addons = {'said', 'sent', 'found', 'including', 'today', 'announced', 'week', 'basically', 'also', 'chars', '\r\n'}
   
    # Create a tokenized list of the words
    doc = nlp(str_words)
    doc_words = ' '.join(str(e) for e in doc)
    tok = word_tokenize(doc_words)
    result = [word.lower() for word in tok]
    lemma_words = ' '.join(str(e) for e in result)
    
    # Lemmatize words into root words
    lemma_result = lemmatizer.lemmatize(lemma_words)
        
    # Convert the words to lowercase
    lower_result = [lemma_result.lower() for word in lemma_result]
    re_words = ' '.join(str(e) for e in lower_result)
    
    # Remove the stop words
    re_words = word_tokenize(re_words)
    tokens = [word.lower() for word in re_words if word.lower() not in sw.union(sw_addons)]
        
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df["tokens"] = bitcoin_df["text"].apply(tokenizer)
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-01-12  When Denis Rusinovich set up cryptocurrency mi...    0.0000
# 1  2022-01-25  El Salvador introduced Bitcoin as a legal tend...    0.3182
# 2  2022-01-14  Were officially building an open Bitcoin minin...   -0.4404
# 3  2022-01-27  Israeli national Tal Prihar pled guilty to rou...   -0.3182
# 4  2022-01-20  In a new blog post the company said that 4,836...    0.0000
#
#    positive  negative  neutral  \
# 0     0.000     0.000    1.000
# 1     0.105     0.000    0.895
# 2     0.000     0.083    0.917
# 3     0.045     0.084    0.871
# 4     0.000     0.000    1.000
#
#                                               tokens
# 0  [denis, rusinovich, set, cryptocurrency, minin...
# 1  [el, salvador, introduced, bitcoin, legal, ten...
# 2  [officially, building, open, bitcoin, mining, ...
# 3  [israeli, national, tal, prihar, pled, guilty,...
# 4  [new, blog, post, company, eth, bitcoin, taken...

# %%
# Create a new tokens column for Ethereum
ethereum_df["tokens"] = ethereum_df["text"].apply(tokenizer)
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-01-20  In a new blog post the company said that 4,836...    0.0000
# 1  2022-01-19  Hackers who made off with roughly $15 million ...    0.0000
# 2  2022-01-20  On some level, the new mayor is simply employi...    0.1779
# 3  2022-01-21  Back in September\r\n, Robinhood announced pla...    0.0772
# 4  2022-01-20  Trading platform Crypto.com lost about $34 mil...   -0.1027
#
#    positive  negative  neutral  \
# 0     0.000     0.000    1.000
# 1     0.000     0.000    1.000
# 2     0.052     0.000    0.948
# 3     0.038     0.000    0.962
# 4     0.056     0.067    0.877
#
#                                               tokens
# 0  [new, blog, post, company, eth, bitcoin, taken...
# 1  [hackers, made, roughly, million, ethereum, at...
# 2  [level, new, mayor, simply, employing, politic...
# 3  [back, september, robinhood, plans, test, cryp...
# 4  [trading, platform, lost, million, worth, cryp...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_grams = ngrams(tokenizer(bitcoin_df["text"].str.cat()), n=2)
Counter(btc_grams).most_common(20)
# Out:
# [(('bitcoin', 'mining'), 14952),
#  (('mining', 'system'), 14952),
#  (('el', 'salvador'), 11214),
#  (('illustration', 'alex'), 11214),
#  (('alex', 'castro'), 11214),
#  (('castro', 'verge'), 11214),
#  (('building', 'open'), 11214),
#  (('open', 'bitcoin'), 11214),
#  (('blog', 'post'), 11214),
#  (('alongside', 'us'), 7476),
#  (('us', 'dollar'), 7476),
#  (('international', 'monetary'), 7476),
#  (('monetary', 'fund'), 7476),
#  (('officially', 'building'), 7476),
#  (('images', 'block'), 7476),
#  (('new', 'blog'), 7476),
#  (('post', 'company'), 7476),
#  (('jack', 'dorsey'), 7476),
#  (('denis', 'rusinovich'), 3738),
#  (('rusinovich', 'set'), 3738)]

# %%
# Generate the Ethereum N-grams where N=2
eth_grams = ngrams(tokenizer(ethereum_df["text"].str.cat()), n=2)
Counter(eth_grams).most_common(20)
# Out:
# [(('blog', 'post'), 10641),
#  (('new', 'blog'), 7094),
#  (('post', 'company'), 7094),
#  (('according', 'new'), 7094),
#  (('new', 'york'), 7094),
#  (('york', 'city'), 7094),
#  (('believers', 'open'), 7094),
#  (('open', 'public'), 7094),
#  (('public', 'blockchains'), 7094),
#  (('blockchains', 'provide'), 7094),
#  (('provide', 'second'), 7094),
#  (('second', 'chance'), 7094),
#  (('chance', 'building'), 7094),
#  (('building', 'digital'), 7094),
#  (('digital', 'economy'), 7094),
#  (('economy', 'fact'), 7094),
#  (('fact', 'applications'), 7094),
#  (('applications', 'built'), 7094),
#  (('built', 'top'), 7094),
#  (('top', 'blockchains'), 7094)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_words = tokenizer(bitcoin_df["text"].str.cat())
top10_btc_words = token_count(btc_words, 10)
print(top10_btc_words)
# Out:
# [('bitcoin', 56070), ('cryptocurrency', 26166), ('mining', 26166), ('company', 26166), ('new', 26166), ('open', 18690), ('el', 14952), ('building', 14952), ('system', 14952), ('salvador', 11214)]

# %%
# Use token_count to get the top 10 words for Ethereum
eth_words = tokenizer(ethereum_df["text"].str.cat())
top10_eth_words = token_count(eth_words, 10)
print(top10_eth_words)
# Out:
# [('ethereum', 28376), ('new', 24829), ('bitcoin', 21282), ('cryptocurrency', 21282), ('company', 14188), ('digital', 14188), ('blockchains', 14188), ('blog', 10641), ('post', 10641), ('taken', 10641)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud

word_cloud = WordCloud(width=400,height=330,colormap='tab20c',collocations=True).generate(str(top10_btc_words))
plt.imshow(word_cloud)
plt.axis("off")
fontdict = {"fontsize": 15, "fontweight": "bold"}
plt.title("Bitcoin Word Cloud", fontdict=fontdict)
plt.show()

# %%
# Generate the Ethereum word cloud
word_cloud_eth = WordCloud(width=400,height=330,colormap='tab20c',collocations=True).generate(str(top10_eth_words))
plt.imshow(word_cloud_eth)
plt.axis("off")
fontdict = {"fontsize": 15, "fontweight": "bold"}
plt.title("Ethereum Word Cloud", fontdict=fontdict)
plt.show()

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
all_btc_text = bitcoin_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(all_btc_text)

# Add a title to the document
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Denis Rusinovich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  set up cryptocurrency mining company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maveric Group
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kazakhstan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he thought he had hit the jackpot. Next door to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the country had everything a Bitcoin … [+4140
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  introduced
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as a legal tender alongside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . | Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The International Monetary Fund’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  executive board has recommended
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El …
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Photo by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Raedle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Block, the payment company formerly known as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Square
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , is working on building an open Bitcoin mining system, it… [+2078 chars]Israeli national
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tal Prihar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  /
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Verge
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# In the culmination of a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  legal process, … [+1448 chars]In a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left:

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text + ':   ' + ent.label_)
# Out:
# Denis Rusinovich:   PERSON
# Maveric Group:   ORG
# Kazakhstan:   GPE
# 2017:   DATE
# China:   GPE
# Russia:   GPE
# chars]El Salvador:   GPE
# Bitcoin:   ORG
# US:   GPE
# 2021:   DATE
# Alex Castro:   PERSON
# Verge:   ORG
# The International Monetary Fund’s:   ORG
# El …:   ORG
# Joe Raedle:   PERSON
# Square:   FAC
# Tal Prihar:   PERSON
# Alex Castro:   PERSON
# The Verge
# :   WORK_OF_ART
# two-year:   DATE
# 4,836:   CARDINAL
# ETH:   ORG
# 443:   CARDINAL
# Alex Castro:   PERSON
# The Verge
# :   WORK_OF_ART
# the early hours of Thursday:   TIME
# morning:   TIME
# Saturday:   DATE
# more than 50%:   PERCENT
# November:   DATE
# more than $:   MONEY
# Jack Dorsey:   PERSON
# Twitter:   WORK_OF_ART
# first:   ORDINAL
# October last year:   DATE
# Elon Musk:   PERSON
# Friday:   DATE
# Fintech:   ORG
# New York City:   GPE
# Richard ODell Poulden:   PERSON
# October:   DATE
# Poulde:   GPE
# chars]Russia:   GPE
# Thursday:   DATE
# Russian:   NORP
# El Salvador:   GPE
# US:   GPE
# The International Monetary Fund:   ORG
# El Salvador:   GPE
# Changpeng:   PERSON
# Zhao:   PERSON
# Binance:   PERSON
# Reuters:   ORG
# Jan 26:   DATE
# Reuters:   ORG
# The U.S. Securities and Exchange Commission:   ORG
# Thursday:   DATE
# Fidelitys Wise Origin Bitcoin:   ORG
# +202:   PERSON
# Dorsey:   PERSON
# June:   DATE
# Joe Raedle/:   PERSON
# this week:   DATE
# September:   DATE
# Robinhood:   ORG
# Crypto.com:   ORG
# about $34 million:   MONEY
# Monday:   DATE
# overnight:   TIME
# European Securities and Ma:   ORG
# 1:   CARDINAL
# Reuters:   ORG
# thousands:   CARDINAL
# 202:   CARDINAL

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
all_eth_text = ethereum_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc_eth = nlp(all_eth_text)

# Add a title to the document
doc_eth.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc_eth, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  /
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Verge
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# In a blog post published in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early hours of Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , cryptocurrency… [+2004 chars]Hackers who made off with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in ethereum from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are attempting to launder the funds through a so-called ethereum mixer, known as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tornado Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , according to a new report from… [+3891 chars]On some level, the new mayor is simply employing an age-old political strategy: making overtures to the business community.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fintech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a growing field in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and blockchain-based companies… [+1562 chars]Back in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robinhood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availa… [+1069 chars]Trading platform
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  lost
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about $34 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of cryptocurrency in a hack on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to a new blog post by the company published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     overnight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </br>--
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saul AlinskyEthereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is a digital platform that runs on blockchain technology. It's most commonly known for its smart contract functionality and native cryptocurrency, ether. The broader purpose of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  … [+10591 chars]Investors interest and growing cryptocurrency uptake helped
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  surge
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     418%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="backgrou

# %%
# List all Entities
for ent in doc_eth.ents:
    print(ent.text + ':   ' + ent.label_)
# Out:
# 4,836:   CARDINAL
# ETH:   ORG
# 443:   CARDINAL
# Alex Castro:   PERSON
# The Verge
# :   WORK_OF_ART
# the early hours of Thursday:   TIME
# morning:   TIME
# roughly $15 million:   MONEY
# Crypto.com:   ORG
# Tornado Cash:   PERSON
# Fintech:   ORG
# New York City:   GPE
# September:   DATE
# Robinhood:   ORG
# Crypto.com:   ORG
# about $34 million:   MONEY
# Monday:   DATE
# overnight:   TIME
# Saul AlinskyEthereum:   PERSON
# Ethereum:   PERSON
# Ethereum:   ORG
# 418%:   PERCENT
# 2021:   DATE
# AMC Entertainment:   ORG
# AMC:   ORG
# GameStop:   ORG
# GME:   ORG
# Ethereums:   PERSON
# more than 650%:   PERCENT
# utopian:   NORP
# Vitalik Buterin:   PERSON
# Ethereum:   ORG
# OPEN:   ORG
# second:   ORDINAL
# OPEN:   ORG
# second:   ORDINAL
# Bloomberg TV:   ORG
# Crypto.com:   ORG
# Kris Marszalek:   PERSON
# 400:   CARDINAL
# Richard ODell Poulden:   PERSON
# October:   DATE
# Poulde:   GPE
# TIME:   ORG
# Metaverse:   ORG
# weekly:   DATE
# Vita:   PERSON
# York City:   GPE
# Eric Adams:   PERSON
# first:   ORDINAL
# Friday:   DATE
# Bitcoin and Ethereum:   ORG
# Coinbase Global Inc.:   ORG
# U.S.:   GPE
# Skiff:   ORG
# MetaMask:   PRODUCT
# Skiff:   ORG
# Ethereum:   PERSON
# January 8, 2021:   DATE
# REUTERS:   ORG
# Dado Ruvic/File PhotoJan:   ORG
# 21:   CARDINAL
# Reuters:   ORG
# 9.28%:   PERCENT
# 36:   MONEY
# June 29, 2021:   DATE
# REUTERS:   ORG
# Dado Ruvic/Illustration
# :   ORG
# MOSCOW:   GPE
# Jan:   PERSON
# Fed:   ORG

# %% [markdown]
# ---
